# %%
#библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.inspection import permutation_importance
from sklearn.model_selection import RandomizedSearchCV

# Загрузка данных
data = pd.read_csv('train.csv')

# %%
# Информация по данным

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   Gender                object
#  2   Age                   int64
#  3   Driving_License       int64
#  4   Region_Code           float64
#  5   Previously_Insured    int64
#  6   Vehicle_Age           object
#  7   Vehicle_Damage        object
#  8   Annual_Premium        float64
#  9   Policy_Sales_Channel  float64
#  10  Vintage               int64
#  11  Response              int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 457.8+ MB

# %%
data.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
# 3   3  Female   35                1          1.0                   0
# 4   4  Female   36                1         15.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes         65101.0                 124.0      187
# 1   > 2 Years            Yes         58911.0                  26.0      288
# 2    < 1 Year             No         38043.0                 152.0      254
# 3    1-2 Year            Yes          2630.0                 156.0       76
# 4    1-2 Year             No         31951.0                 152.0      294
#
#    Response
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %%
#Проверка на повторы и их удаление, количество строк и столбцов
data.duplicated().sum()
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (5000000, 12)

# %%
#Проверка на нулевые значения
missing_values = data.isnull().sum()
missing_values
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %% [markdown]
# 1. Столбик id, нам не пригодится
# 2. Гендер владельца машины, предварительно оставим (преобразование 0/1)
# 3. Наличие водительских прав, оставляем
# 4. Регион автомобиля убираем
# 5. Была ли до этого страховка, оставляем
# 6. Возраст машины, оставляем
# 7. Повреждения машины, оставляем
# 8. Годовая сумма страховки, финансовый показатель оставляем
# 9. Канал сбыта страховки??? убираем
# 10. Винтажность машины, убираем
# 11. Итоговый ответ для каждого покупателя страховки, возьмет или нет ее в итоге, оставляем

# %%
# Оставляем только полезные столбцы
columns_to_keep = ['Gender', 'Age', 'Driving_License', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium']
data = data[columns_to_keep]

# %%
data
# Out:
#          Gender  Age  Driving_License  Previously_Insured Vehicle_Age  \
# 0          Male   21                1                   0    1-2 Year
# 1          Male   43                1                   0   > 2 Years
# 2        Female   25                1                   1    < 1 Year
# 3        Female   35                1                   0    1-2 Year
# 4        Female   36                1                   1    1-2 Year
# ...         ...  ...              ...                 ...         ...
# 4999995  Female   74                1                   0    1-2 Year
# 4999996  Female   23                1                   1    < 1 Year
# 4999997  Female   35                1                   1    1-2 Year
# 4999998  Female   38                1                   0    1-2 Year
# 4999999    Male   61                1                   0   > 2 Years
#
#         Vehicle_Damage  Annual_Premium
# 0                  Yes         65101.0
# 1                  Yes         58911.0
# 2                   No         38043.0
# 3                  Yes          2630.0
# 4                   No         31951.0
# ...                ...             ...
# 4999995             No          2630.0
# 4999996             No         35818.0
# 4999997             No         30307.0
# 4999998            Yes         28302.0
# 4999999            Yes         41372.0
#
# [5000000 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 7 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Gender              object
#  1   Age                 int64
#  2   Driving_License     int64
#  3   Previously_Insured  int64
#  4   Vehicle_Age         object
#  5   Vehicle_Damage      object
#  6   Annual_Premium      float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 267.0+ MB

# %%
# One-hot кодирование категориальных признаков
categorical_features = ['Gender', 'Vehicle_Damage']
data = pd.get_dummies(data, columns=categorical_features, drop_first=True)
data_o = data
data_o = pd.get_dummies(data, columns=['Vehicle_Age'], prefix='Vehicle_Age')
data_o
#Преобразование 1/0 для текстовых фичей
# Out:
#          Age  Driving_License  Previously_Insured  Annual_Premium  \
# 0         21                1                   0         65101.0
# 1         43                1                   0         58911.0
# 2         25                1                   1         38043.0
# 3         35                1                   0          2630.0
# 4         36                1                   1         31951.0
# ...      ...              ...                 ...             ...
# 4999995   74                1                   0          2630.0
# 4999996   23                1                   1         35818.0
# 4999997   35                1                   1         30307.0
# 4999998   38                1                   0         28302.0
# 4999999   61                1                   0         41372.0
#
#          Gender_Male  Vehicle_Damage_Yes  Vehicle_Age_1-2 Year  \
# 0               True                True                  True
# 1               True                True                 False
# 2              False               False                 False
# 3              False                True                  True
# 4              False               False                  True
# ...              ...                 ...                   ...
# 4999995        False               False                  True
# 4999996        False               False                 False
# 4999997        False               False                  True
# 4999998        False                True                  True
# 4999999         True                True                 False
#
#          Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years
# 0                       False                  False
# 1                       False                   True
# 2                        True                  False
# 3                       False                  False
# 4                       False                  False
# ...                       ...                    ...
# 4999995                 False                  False
# 4999996                  True                  False
# 4999997                 False                  False
# 4999998                 False                  False
# 4999999                 False                   True
#
# [5000000 rows x 9 columns]

# %%
# Нормализация числовых признаков
numeric_features = ['Age', 'Annual_Premium']
scaler = StandardScaler()
data_o[numeric_features] = scaler.fit_transform(data[numeric_features])

# %%
data_o
# Out:
#               Age  Driving_License  Previously_Insured  Annual_Premium  \
# 0       -1.159421                1                   0        2.101969
# 1        0.307562                1                   0        1.726275
# 2       -0.892697                1                   1        0.459720
# 3       -0.225886                1                   0       -1.689623
# 4       -0.159205                1                   1        0.089975
# ...           ...              ...                 ...             ...
# 4999995  2.374675                1                   0       -1.689623
# 4999996 -1.026059                1                   1        0.324677
# 4999997 -0.225886                1                   1       -0.009805
# 4999998 -0.025843                1                   0       -0.131496
# 4999999  1.507821                1                   0        0.661770
#
#          Gender_Male  Vehicle_Damage_Yes  Vehicle_Age_1-2 Year  \
# 0               True                True                  True
# 1               True                True                 False
# 2              False               False                 False
# 3              False                True                  True
# 4              False               False                  True
# ...              ...                 ...                   ...
# 4999995        False               False                  True
# 4999996        False               False                 False
# 4999997        False               False                  True
# 4999998        False                True                  True
# 4999999         True                True                 False
#
#          Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years
# 0                       False                  False
# 1                       False                   True
# 2                        True                  False
# 3                       False                  False
# 4                       False                  False
# ...                       ...                    ...
# 4999995                 False                  False
# 4999996                  True                  False
# 4999997                 False                  False
# 4999998                 False                  False
# 4999999                 False                   True
#
# [5000000 rows x 9 columns]

# %%
scaler.scale_
# Out:
# array([1.49967624e+01, 1.64761953e+04])

# %%
scaler.mean_
# Out:
# array([   38.387563 , 30468.5561096])

# %%
(30468.5561096 - 29.6420927)/14.4827517
# Out:
# 2101.7355435914847

# %%
data_o
# Out:
#               Age  Driving_License  Previously_Insured  Annual_Premium  \
# 0       -1.159421                1                   0        2.101969
# 1        0.307562                1                   0        1.726275
# 2       -0.892697                1                   1        0.459720
# 3       -0.225886                1                   0       -1.689623
# 4       -0.159205                1                   1        0.089975
# ...           ...              ...                 ...             ...
# 4999995  2.374675                1                   0       -1.689623
# 4999996 -1.026059                1                   1        0.324677
# 4999997 -0.225886                1                   1       -0.009805
# 4999998 -0.025843                1                   0       -0.131496
# 4999999  1.507821                1                   0        0.661770
#
#          Gender_Male  Vehicle_Damage_Yes  Vehicle_Age_1-2 Year  \
# 0               True                True                  True
# 1               True                True                 False
# 2              False               False                 False
# 3              False                True                  True
# 4              False               False                  True
# ...              ...                 ...                   ...
# 4999995        False               False                  True
# 4999996        False               False                 False
# 4999997        False               False                  True
# 4999998        False                True                  True
# 4999999         True                True                 False
#
#          Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years
# 0                       False                  False
# 1                       False                   True
# 2                        True                  False
# 3                       False                  False
# 4                       False                  False
# ...                       ...                    ...
# 4999995                 False                  False
# 4999996                  True                  False
# 4999997                 False                  False
# 4999998                 False                  False
# 4999999                 False                   True
#
# [5000000 rows x 9 columns]

# %%
import seaborn as sns
sns.heatmap(data_o.corr(), cmap='coolwarm', annot=True);

# %%
data = pd.read_csv('train.csv')
data.Response.value_counts()
# Out:
# Response
# 0    4384718
# 1     615282
# Name: count, dtype: int64

# %% [markdown]
# ---

# %%
# Разделение на признаки (X) и целевую переменную (y)
X = data_o
y = data['Response']

# Разделение на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %%
X_train
# Out:
#               Age  Driving_License  Previously_Insured  Annual_Premium  \
# 813726   0.841011                1                   0        0.902056
# 341719  -0.159205                1                   0       -0.191704
# 4270474 -0.892697                1                   1        0.525876
# 1177681  0.174200                1                   0       -0.022066
# 1982304  2.107951                1                   0        0.817145
# ...           ...              ...                 ...             ...
# 88386   -0.025843                1                   1        1.059009
# 2446250 -1.159421                1                   0        0.505180
# 3836473 -0.959378                1                   1       -0.338461
# 1296606  1.107735                1                   0        0.289050
# 1510718  1.974589                1                   1       -1.689623
#
#          Gender_Male  Vehicle_Damage_Yes  Vehicle_Age_1-2 Year  \
# 813726          True                True                 False
# 341719          True                True                  True
# 4270474        False               False                 False
# 1177681        False               False                  True
# 1982304        False                True                  True
# ...              ...                 ...                   ...
# 88386           True                True                  True
# 2446250        False               False                 False
# 3836473         True               False                 False
# 1296606         True                True                  True
# 1510718         True               False                  True
#
#          Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years
# 813726                  False                   True
# 341719                  False                  False
# 4270474                  True                  False
# 1177681                 False                  False
# 1982304                 False                  False
# ...                       ...                    ...
# 88386                   False                  False
# 2446250                  True                  False
# 3836473                  True                  False
# 1296606                 False                  False
# 1510718                 False                  False
#
# [3750000 rows x 9 columns]

# %%
# Визуализация пропорций классов
class_proportions = y.value_counts(normalize=True)
plt.figure(figsize=(8, 4))
sns.barplot(x=class_proportions.index, y=class_proportions.values * 100)
plt.title('Class Proportions')
plt.xlabel('Class')
plt.ylabel('Percentage (%)')
plt.xticks(ticks=[0, 1], labels=['Not Survived', 'Survived'])
plt.show()

# Проверка результатов
print("Размер обучающей выборки:", X_train.shape)
print("Размер тестовой выборки:", X_test.shape)
# Out:
# Размер обучающей выборки: (3750000, 9)
# Размер тестовой выборки: (1250000, 9)

# %%
X_train
# Out:
#               Age  Driving_License  Previously_Insured  Annual_Premium  \
# 813726   0.841011                1                   0        0.902056
# 341719  -0.159205                1                   0       -0.191704
# 4270474 -0.892697                1                   1        0.525876
# 1177681  0.174200                1                   0       -0.022066
# 1982304  2.107951                1                   0        0.817145
# ...           ...              ...                 ...             ...
# 88386   -0.025843                1                   1        1.059009
# 2446250 -1.159421                1                   0        0.505180
# 3836473 -0.959378                1                   1       -0.338461
# 1296606  1.107735                1                   0        0.289050
# 1510718  1.974589                1                   1       -1.689623
#
#          Gender_Male  Vehicle_Damage_Yes  Vehicle_Age_1-2 Year  \
# 813726          True                True                 False
# 341719          True                True                  True
# 4270474        False               False                 False
# 1177681        False               False                  True
# 1982304        False                True                  True
# ...              ...                 ...                   ...
# 88386           True                True                  True
# 2446250        False               False                 False
# 3836473         True               False                 False
# 1296606         True                True                  True
# 1510718         True               False                  True
#
#          Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years
# 813726                  False                   True
# 341719                  False                  False
# 4270474                  True                  False
# 1177681                 False                  False
# 1982304                 False                  False
# ...                       ...                    ...
# 88386                   False                  False
# 2446250                  True                  False
# 3836473                  True                  False
# 1296606                 False                  False
# 1510718                 False                  False
#
# [3750000 rows x 9 columns]

# %%
y_train
# Out:
# 813726     0
# 341719     1
# 4270474    0
# 1177681    0
# 1982304    0
#           ..
# 88386      0
# 2446250    0
# 3836473    0
# 1296606    1
# 1510718    0
# Name: Response, Length: 3750000, dtype: int64

# %% [markdown]
# ---

# %%
'''# 1. Decision Tree
tree_param_grid = {'max_depth': [3, 5, 10], 'min_samples_split': [5, 10, 15]}
tree_model = GridSearchCV(DecisionTreeClassifier(random_state=42), tree_param_grid, cv=5)
tree_model.fit(X_train, y_train)
print("Decision Tree Best Params:", tree_model.best_params_)
'''
#2. Random Forest RandomSearchCV
from lightgbm import LGBMClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer, fbeta_score, f1_score, precision_score
import numpy as np

# Параметры, оптимизированные для баланса между precision/recall
lgb_params = {
    'n_estimators': [200, 300, 500, 700], #количество деревьев в модели
    'max_depth': [5, 7, 10, 15],  # Глубина дерева, ограничиваем глубину для снижения переобучения
    'learning_rate': [0.01, 0.03, 0.05, 0.1],  # Скорость обучения, шаг на каждой итерации
    'num_leaves': [31, 50, 70, 100],  # "Листья" модели, сложность
    'min_child_samples': [100, 200, 300, 500],  # Сочетается с листьями для уменьшения сложности
    'subsample': [0.7, 0.8, 0.9], # Доля строк для обучения каждого дерева (без замены)0.7 = используем 70% строк для дерева
    'colsample_bytree': [0.7, 0.8, 0.9], # Доля признаков (колонок) для каждого дерева
    'reg_alpha': [0.1, 0.5, 1, 5],  # Усиленная L1-регуляризация
    'reg_lambda': [0.1, 0.5, 1, 5],  # Усиленная L2-регуляризация
    'min_split_gain': [0.01, 0.1, 0.5, 1.0],  # Если улучшение < этого, не делаем split
    'min_child_weight': [0.001, 0.01, 0.1, 1],  # Помогает контролировать размер листьев
    'scale_pos_weight': [3, 5, 7, 10]  # Умеренные значения (дисбаланс ~7:1) Даёт вес положительному классу
}

# F1-scorer как основная метрика
f1_scorer = make_scorer(f1_score, pos_label=1)

lgb_model = RandomizedSearchCV(
    LGBMClassifier(
        random_state=42,
        n_jobs=-1,
        verbose=-1,
        boosting_type='gbdt',
        objective='binary',
        metric='binary_logloss',
        # УБИРАЕМ конфликтующие параметры:
        # class_weight='balanced',  # КОНФЛИКТ с scale_pos_weight
        # is_unbalance=True,  # КОНФЛИКТ с scale_pos_weight
    ),
    lgb_params,
    n_iter=50,  # Увеличили для лучшего поиска
    cv=3,  # Увеличили CV для надежности
    n_jobs=-1,  # Используем все ядра
    verbose=2,
    scoring=f1_scorer,  # F1 как решающая метрика
    random_state=42,
    refit=True
)

lgb_model.fit(X_train, y_train)
print("LightGBM Best Params:", lgb_model.best_params_)
print("Best F1 Score:", lgb_model.best_score_)

# КРИТИЧНО: Калибровка порога для баланса precision/recall
from sklearn.metrics import precision_recall_curve, classification_report

# Предсказываем вероятности
y_proba = lgb_model.predict_proba(X_test)[:, 1]

# Находим оптимальный порог для целевого precision
precisions, recalls, thresholds = precision_recall_curve(y_test, y_proba)
f1_scores = 2 * (precisions * recalls) / (precisions + recalls + 1e-10)

# Находим порог с максимальным F1 (или можно задать минимальный precision)
optimal_idx = np.argmax(f1_scores)
optimal_threshold = thresholds[optimal_idx]
print(f"\nОптимальный порог: {optimal_threshold:.4f}")
print(f"Precision: {precisions[optimal_idx]:.4f}, Recall: {recalls[optimal_idx]:.4f}, F1: {f1_scores[optimal_idx]:.4f}")

# Предсказываем с новым порогом
y_pred_adjusted = (y_proba >= optimal_threshold).astype(int)
print("\n--- Результаты с оптимизированным порогом ---")
print(classification_report(y_test, y_pred_adjusted))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# LightGBM Best Params: {'subsample': 0.7, 'scale_pos_weight': 3, 'reg_lambda': 1, 'reg_alpha': 1, 'num_leaves': 70, 'n_estimators': 200, 'min_split_gain': 1.0, 'min_child_weight': 0.1, 'min_child_samples': 500, 'max_depth': 7, 'learning_rate': 0.05, 'colsample_bytree': 0.9}
# Best F1 Score: 0.45164672646429044
#
# Оптимальный порог: 0.4648
# Precision: 0.3156, Recall: 0.7980, F1: 0.4523
#
# --- Результаты с оптимизированным порогом ---
#               precision    recall  f1-score   support
#
#            0       0.96      0.76      0.85   1096180
#            1       0.32      0.80      0.45    153820
#
#     accuracy                           0.76   1250000
#    macro avg       0.64      0.78      0.65   1250000
# weighted avg       0.88      0.76      0.80   1250000

# %%
# Функция для оценки модели
def evaluate_model(model, name):
    print(f"\n--- {name} ---")
    y_pred = model.predict(X_test)

    # Матрица ошибок
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Response', 'Responce'], yticklabels=['No Response', 'Responce'])
    plt.title(f'Confusion Matrix for {name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    # Отчет классификации
    print(classification_report(y_test, y_pred))

    # Важность признаков (для деревьев и LihgtGBM)
    if hasattr(model.best_estimator_, "feature_importances_"):
        feature_importances = model.best_estimator_.feature_importances_
        feature_names = X.columns
        importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
        importance_df = importance_df.sort_values(by='Importance', ascending=False)
        print("\nFeature Importances:")
        print(importance_df.head(10))

# Оценка моделей
#evaluate_model(tree_model, "Decision Tree")
evaluate_model(lgb_model, "Random Forest")
# Out:
# --- Random Forest ---
#               precision    recall  f1-score   support
#
#            0       0.96      0.78      0.86   1096180
#            1       0.32      0.74      0.45    153820
#
#     accuracy                           0.78   1250000
#    macro avg       0.64      0.76      0.66   1250000
# weighted avg       0.88      0.78      0.81   1250000
#
#
# Feature Importances:
#                  Feature  Importance
# 3         Annual_Premium        5959
# 0                    Age        5227
# 4            Gender_Male         486
# 6   Vehicle_Age_1-2 Year         422
# 7   Vehicle_Age_< 1 Year         274
# 5     Vehicle_Damage_Yes         223
# 8  Vehicle_Age_> 2 Years         178
# 2     Previously_Insured         157
# 1        Driving_License          94

# %%
import pickle

# Сохранение модели в файл
model_filename = "lgb_model.pkl"
with open(model_filename, 'wb') as file:
    pickle.dump(lgb_model, file)
print(f"Модель сохранена в файл: {model_filename}")
# Out:
# Модель сохранена в файл: lgb_model.pkl
